# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
g = nx.grid_2d_graph(3,3)
h = nx.grid_2d_graph(4,4)

h= nx.relabel_nodes(h,{n:"h1"+str(n) for n in h.nodes()})
g= nx.compose(g,h)

h = nx.grid_2d_graph(3,3)
h= nx.relabel_nodes(h,{n:"h2"+str(n) for n in h.nodes()})
g= nx.compose(g,h)

g.add_edge((0,0),"bridge")
g.add_edge("bridge","h1(0, 0)")
g.add_edge("bridge","h2(0, 0)")


g.add_edge((0,0),"hub")
g.add_edge((0,1),"hub")
g.add_edge("h1(2, 3)","hub")
g.add_edge("sing1","hub")
g.add_edge("sing2","hub")

g.add_edge("sing1","hub2")
g.add_edge("s1","hub2")
g.add_edge("s2","hub2")
g.add_edge("s3","hub2")
g.add_edge("s4","hub2")
g.add_edge("s5","hub2")
for i in range(1,5):
  g.add_edge("s"+str(i),"ch"+str(i)+"_1")
  g.add_edge("s"+str(i),"ch"+str(i)+"_2")

g.add_edge("sing2","hub3")
g.add_edge("s6","hub3")
g.add_edge("s7","hub3")
g.add_edge("s8","hub3")
g.add_edge("s9","hub3")
g.add_edge("s10","hub3")

# %%
nx.draw(g)

# %%
#zkc = nx.erdos_renyi_graph(20,0.1,directed=True)
#zkc = nx.random_geometric_graph(20,0.4)
# g = nx.grid_2d_graph(10,10)
# g = nx.watts_strogatz_graph(40,4,0.1)
# g = nx.bfs_tree(g,0)
# g = g.reverse()

# %%
pos = nx.spring_layout(g,iterations=10000)

# %%
centralities = dict()
centralities["pagerank"] = nx.pagerank(g)
centralities["betweenness"] = nx.betweenness_centrality(g)
centralities["Clustering Coefficient"] = nx.clustering(g)
centralities["Katz"] = nx.katz_centrality(g,max_iter=1000)
centralities["Eigenvector"] = nx.eigenvector_centrality_numpy(g)
centralities["Degree"] = nx.degree(g)
centralities["Closeness"] = nx.closeness_centrality(g)
centralities["Harmonic"] =nx.harmonic_centrality(g)

node_order = g.nodes()

# %%
for name,centrality in centralities.items():
  print(name)
  nx.draw(g,pos=pos, node_color=[centrality[n] for n in node_order],cmap=plt.cm.Reds)
  plt.savefig("example"+name+".pdf")
  plt.show()
# Out:
# pagerank
# betweenness
# Clustering Coefficient
# Katz
# Eigenvector
# Degree
# Closeness
# Harmonic

# %%
nx.draw(zkc,pos=pos, node_color=[deg[n] for n in node_order],cmap=plt.cm.Reds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-e73ce66d3f24> in <module>()
# ----> 1 nx.draw(zkc,pos=pos, node_color=[deg[n] for n in node_order],cmap=plt.cm.Reds)
#
# NameError: name 'zkc' is not defined

# %%
nx.draw(zkc,pos=pos, node_color=[eig[n] for n in node_order],cmap=plt.cm.Reds)

# %%
plt.colorbar(plt.cm.Reds(range(10)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-151-a61daa290fc7> in <module>()
# ----> 1 plt.colorbar(plt.cm.Reds(range(10)))
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in colorbar(mappable, cax, ax, **kw)
#    2007     if ax is None:
#    2008         ax = gca()
# -> 2009     ret = gcf().colorbar(mappable, cax=cax, ax=ax, **kw)
#    2010     return ret
#    2011 colorbar.__doc__ = matplotlib.colorbar.colorbar_doc
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    2236                              'panchor']
#    2237         cb_kw = {k: v for k, v in kw.items() if k not in NON_COLORBAR_KEYS}
# -> 2238         cb = cbar.colorbar_factory(cax, mappable, **cb_kw)
#    2239
#    2240         self.sca(current_ax)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/colorbar.py in colorbar_factory(cax, mappable, **kwargs)
#    1683         cb = ColorbarPatch(cax, mappable, **kwargs)
#    1684     else:
# -> 1685         cb = Colorbar(cax, mappable, **kwargs)
#    1686
#    1687     cid = mappable.callbacksSM.connect('changed', cb.on_mappable_changed)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/colorbar.py in __init__(self, ax, mappable, **kw)
#    1203         # Ensure the given mappable's norm has appropriate vmin and vmax set
#    1204         # even if mappable.draw has not yet been called.
# -> 1205         if mappable.get_array() is not None:
#    1206             mappable.autoscale_None()
#    1207
#
# AttributeError: 'numpy.ndarray' object has no attribute 'get_array'

# %%
import numpy as np 
g=nx.erdos_renyi_graph(5000,0.005)
L = nx.adj_matrix(g)
e = np.linalg.eigvals(L.A)
print("Largest eigenvalue:", max(e))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: adj_matrix is deprecated and will be removed in version 3.0.
# Use `adjacency_matrix` instead
#
#   This is separate from the ipykernel package so we can avoid doing imports until
# Largest eigenvalue: 26.021081596275685

# %%
np.average(list(dict(g.degree).values()))
# Out:
# 24.9812

# %%
np.max(list(dict(g.degree).values()))
# Out:
# 14

# %%
np.sqrt(20)
# Out:
# 4.47213595499958
